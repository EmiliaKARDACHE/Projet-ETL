# %% [markdown]
# # Exploration du fichier Agribalyse_detail_par_ingredient.csv
#
# Ce notebook permet d'explorer et de visualiser le fichier Agribalyse_detail_par_ingredient.csv à l'aide de pandas et matplotlib.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Chemin du fichier : AGB32_agricole_conventionnel
csv_path1 = r"C:\Users\emili\OneDrive\Bureau\Projet-ETL\data\raw\AGRIBALYSE\extract_AGB32_agricole_conv.csv"
# Lecture (auto-détection du séparateur)
df = pd.read_csv(csv_path1, sep=None, engine="python", encoding="utf-8") 
df.head(10)
# Out:
#                           Nom du Produit en Français  \
# 0  Abricot, conventionnel, moyenne nationale, au ...
# 1  Agneau système de production conventionnel en ...
# 2  Agneau, conventionnel, système Roquefort, à la...
# 3  Algue production non optimisée, 1 kg d'algues ...
# 4  Algue production optimisée, 1 kg d'algues (Lam...
# 5  Ananas, production mixte, à la ferme, île de l...
# 6  Anchois européenne, Engraulis encrasicolus, at...
# 7  Avoine, moyenne nationale, alimentation animal...
# 8       Banane conventionnelle, à la ferme, Antilles
# 9  Bar ou daurade, 200-500g, conventionnel, en ca...
#
#                                             LCI Name Type de production  \
# 0  Apricot, conventional, national average, at or...            Culture
# 1  Lamb, conventional, indoor production system, ...            Elevage
# 2  Lamb, conventional, Roquefort system, at farm ...            Elevage
# 3  Seaweed non-optimized production, 1kg algae (L...        Aquaculture
# ...

# %%
# Chemin du fichier : Agribalyse_detail_par_ingredient
csv_path = r"C:\Users\emili\OneDrive\Bureau\Projet-ETL\data\raw\AGRIBALYSE\Agribalyse_detail_par_ingredient.csv"
#Lecture (auto-détection du séparateur)
df = pd.read_csv(csv_path, sep=None, engine="python", encoding="utf-8") 
df.head(10)
